# %%
import pandas as pd

df = pd.read_csv("wait_times_2015_2024.csv")
print(df.head(10))
# Out:
#          Date                           Ride  Average Wait Time (mins)  \
# 0  2015-01-01                 Space Mountain                      50.0
# 1  2015-01-01       Indiana Jones™ Adventure                      48.0
# 2  2015-01-01             Peter Pan's Flight                      42.0
# 3  2015-01-01            Alice in Wonderland                      37.0
# 4  2015-01-01   Roger Rabbit's Car Toon Spin                      34.0
# 5  2015-01-01       Pirates of the Caribbean                      28.0
# 6  2015-01-01  Finding Nemo Submarine Voyage                      27.0
# 7  2015-01-01            Matterhorn Bobsleds                      27.0
# 8  2015-01-01   "it's a small world" Holiday                      27.0
# 9  2015-01-01                  Astro Orbitor                      26.0
#
#    Max Wait Time (mins)
# 0                  96.0
# 1                  91.0
# 2                  50.0
# 3                  50.0
# 4                  61.0
# 5                  60.0
# ...
