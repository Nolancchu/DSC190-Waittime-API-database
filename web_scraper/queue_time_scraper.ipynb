# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

def scrape_wait_times(url):
    """
    Scrapes a queue-times.com calendar page for average
    and maximum wait times per ride.
    Returns a DataFrame with columns: Date, Ride, Average Wait Time (mins), Max Wait Time (mins)
    """
    try:
        # 1. Fetch the webpage content
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Check for any request errors

        # 2. Parse the HTML with BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # 3. Extract date from URL (format: /parks/16/calendar/2025/06/11)
        # or use current date as fallback
        url_parts = url.split('/')
        if len(url_parts) >= 7:
            year, month, day = url_parts[-3], url_parts[-2], url_parts[-1]
            date_str = f"{year}-{month}-{day}"
        else:
            date_str = datetime.now().strftime("%Y-%m-%d")

        # 4. Find all tables with class "table is-fullwidth"
        tables = soup.find_all('table', class_='table is-fullwidth')
        
        if not tables:
            print("Warning: Could not find any tables with class 'table is-fullwidth'")
            return pd.DataFrame()
        
        # 5. Create a dictionary to store data by ride name
        rides_data = {}
        
        for idx, table in enumerate(tables):
            print(f"\n--- Table {idx + 1} ---")
            
            # Find all rows in tbody
            tbody = table.find('tbody')
            if not tbody:
                print("Warning: Could not find tbody in table")
                continue
            
            rows = tbody.find_all('tr')
            
            # Extract ride names and wait times
            for row in rows:
                cols = row.find_all('td')
                if len(cols) >= 2:
                    # Get ride name from the first column (extract text from anchor tag if present)
                    ride_link = cols[0].find('a')
                    ride_name = ride_link.get_text(strip=True) if ride_link else cols[0].get_text(strip=True)
                    
                    # Get wait time from the second column (extract from span if present)
                    time_span = cols[1].find('span')
                    wait_time = time_span.get_text(strip=True) if time_span else cols[1].get_text(strip=True)
                    
                    # Initialize ride entry if not exists
                    if ride_name not in rides_data:
                        rides_data[ride_name] = {
                            'Date': date_str,
                            'Ride': ride_name,
                            'Average Wait Time (mins)': None,
                            'Max Wait Time (mins)': None
                        }
                    
                    # Assign to appropriate column based on table number
                    if idx == 0:  # Table 1 is Average
                        rides_data[ride_name]['Average Wait Time (mins)'] = float(wait_time)
                    elif idx == 1:  # Table 2 is Max
                        rides_data[ride_name]['Max Wait Time (mins)'] = float(wait_time)
                    
                    print(f"{ride_name}: {wait_time} mins")
        
        # 6. Convert dictionary to list of dictionaries for DataFrame
        data = list(rides_data.values())
        
        # 7. Create DataFrame
        df = pd.DataFrame(data)
        return df

    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL: {e}")
        return pd.DataFrame()
    except Exception as e:
        print(f"An error occurred: {e}")
        return pd.DataFrame()

# --- Main execution ---
if __name__ == "__main__":
    target_url = "https://queue-times.com/parks/16/calendar/2025/06/11"
    print(f"Scraping wait time forecast for: {target_url}\n")
    df = scrape_wait_times(target_url)
    print(f"\n--- DataFrame ---")
    print(df)
# Out:
# Scraping wait time forecast for: https://queue-times.com/parks/16/calendar/2025/06/11
#
#
# --- Table 1 ---
# Star Wars: Rise of the Resistance: 71 mins
# Space Mountain: 62 mins
# Tiana's Bayou Adventure: 61 mins
# Indiana Jones™ Adventure: 53 mins
# Big Thunder Mountain Railroad: 41 mins
# Roger Rabbit's Car Toon Spin: 34 mins
# Haunted Mansion Holiday: 33 mins
# Mickey's House and Meet Mickey Mouse: 33 mins
# Peter Pan's Flight: 32 mins
# Millennium Falcon: Smugglers Run: 32 mins
# Meet Disney Princesses at Royal Hall: 30 mins
# Carnation Café: 29 mins
# 56  2025-06-11                  Walt Disney's Enchanted Tiki Room
#
#     Average Wait Time (mins)  Max Wait Time (mins)
# 0                       71.0                 100.0
# 1                       62.0                  95.0
# 2                       61.0                 120.0
# 3                       53.0                  90.0
# 4                       41.0                  65.0
# 5                       34.0                  65.0
# 6                       33.0                  65.0
# 7                       33.0                  60.0
# 8                       32.0                  60.0
# 9                       32.0                 115.0
# 10                      30.0                  45.0
# 11                      29.0                  60.0
# 12                      27.0                  60.0
# 13                      27.0                  50.0
# 14                      26.0                  45.0
# 15                      25.0                  55.0
# 16                      23.0                  60.0
# 17                      22.0                  35.0
# 18                      22.0                  85.0
# 19                      21.0                  40.0
# 20                      20.0                  40.0
# 21                      20.0                  45.0
# 22                      19.0                  45.0
# 23                      19.0                  45.0
# 24                      17.0                  40.0
# 25                      15.0                  25.0
# 26                      15.0                  20.0
# 27                      15.0                  15.0
# 28                      14.0                  15.0
# 29                      13.0                  25.0
# 30                      13.0                  25.0
# 31                      12.0                  45.0
# 32                      12.0                  30.0
# 33                      11.0                  20.0
# 34                       7.0                  20.0
# 35                       5.0                  15.0
# 36                       5.0                  20.0
# 37                       5.0                  10.0
# 38                       5.0                   5.0
# 39                       5.0                   5.0
# 40                       NaN                   NaN
# 41                       NaN                   NaN
# 42                       NaN                   NaN
# 43                       NaN                   NaN
# 44                       NaN                   NaN
# 45                       NaN                   NaN
# 46                       NaN                   NaN
# 47                       NaN                   NaN
# 48                       NaN                   NaN
# 49                       NaN                   NaN
# 50                       NaN                   NaN
# 51                       NaN                   NaN
# 52                       NaN                   NaN
# 53                       NaN                   NaN
# 54                       NaN                   NaN
# 55                       NaN                   NaN
# 56                       NaN                   NaN

# %%
df
# Out:
#           Date                                               Ride  \
# 0   2025-06-11                  Star Wars: Rise of the Resistance
# 1   2025-06-11                                     Space Mountain
# 2   2025-06-11                            Tiana's Bayou Adventure
# 3   2025-06-11                           Indiana Jones™ Adventure
# 4   2025-06-11                      Big Thunder Mountain Railroad
# 5   2025-06-11                       Roger Rabbit's Car Toon Spin
# 6   2025-06-11                            Haunted Mansion Holiday
# 7   2025-06-11               Mickey's House and Meet Mickey Mouse
# 8   2025-06-11                                 Peter Pan's Flight
# 9   2025-06-11                   Millennium Falcon: Smugglers Run
# 10  2025-06-11               Meet Disney Princesses at Royal Hall
# 11  2025-06-11                                     Carnation Café
# 12  2025-06-11                                       Cafe Orleans
# 13  2025-06-11                           Pirates of the Caribbean
# 14  2025-06-11                                Alice in Wonderland
# 15  2025-06-11                  Mickey & Minnie's Runaway Railway
# 16  2025-06-11               Star Tours - The Adventures Continue
# 17  2025-06-11             Oga's Cantina at the Disneyland Resort
# 18  2025-06-11                      Finding Nemo Submarine Voyage
# 19  2025-06-11                      Buzz Lightyear Astro Blasters
# 20  2025-06-11                          Dumbo the Flying Elephant
# 21  2025-06-11                                            Autopia
# 22  2025-06-11                                      Astro Orbitor
# 23  2025-06-11                                      Jungle Cruise
# 24  2025-06-11                               Mr. Toad's Wild Ride
# 25  2025-06-11                        Snow White's Enchanted Wish
# 26  2025-06-11                                River Belle Terrace
# 27  2025-06-11                              Sailing Ship Columbia
# 28  2025-06-11                               Mark Twain Riverboat
# 29  2025-06-11                                Disneyland Monorail
# 30  2025-06-11                         Storybook Land Canal Boats
# 31  2025-06-11                               "it's a small world"
# 32  2025-06-11             The Many Adventures of Winnie the Pooh
# 33  2025-06-11                         Pinocchio's Daring Journey
# 34  2025-06-11                                      Mad Tea Party
# 35  2025-06-11                             Casey Jr. Circus Train
# 36  2025-06-11                              King Arthur Carrousel
# 37  2025-06-11                    Davy Crockett's Explorer Canoes
# 38  2025-06-11                                Disneyland Railroad
# 39  2025-06-11                 Pirate's Lair on Tom Sawyer Island
# 40  2025-06-11                              Blue Bayou Restaurant
# 41  2025-06-11                                 Donald's Duck Pond
# 42  2025-06-11                   Frontierland Shootin' Exposition
# 43  2025-06-11                                 Main Street Cinema
# 44  2025-06-11                               Main Street Vehicles
# 45  2025-06-11      Millennium Falcon: Smugglers Run Single Rider
# 46  2025-06-11                                     Minnie's House
# 47  2025-06-11                                          Plaza Inn
# 48  2025-06-11               Tiana's Bayou Adventure Single Rider
# 49  2025-06-11                           Goofy's How-to-Play Yard
# 50  2025-06-11  Adventureland Treehouse inspired by Walt Disne...
# 51  2025-06-11                      Chip 'n' Dale's GADGETcoaster
# 52  2025-06-11                     Great Moments with Mr. Lincoln
# 53  2025-06-11                                Matterhorn Bobsleds
# 54  2025-06-11                 Sleeping Beauty Castle Walkthrough
# 55  2025-06-11                                 The Disney Gallery
# 56  2025-06-11                  Walt Disney's Enchanted Tiki Room
#
#     Average Wait Time (mins)  Max Wait Time (mins)
# 0                       71.0                 100.0
# 1                       62.0                  95.0
# 2                       61.0                 120.0
# 3                       53.0                  90.0
# 4                       41.0                  65.0
# 5                       34.0                  65.0
# 6                       33.0                  65.0
# 7                       33.0                  60.0
# 8                       32.0                  60.0
# 9                       32.0                 115.0
# 10                      30.0                  45.0
# 11                      29.0                  60.0
# 12                      27.0                  60.0
# 13                      27.0                  50.0
# 14                      26.0                  45.0
# 15                      25.0                  55.0
# 16                      23.0                  60.0
# 17                      22.0                  35.0
# 18                      22.0                  85.0
# 19                      21.0                  40.0
# 20                      20.0                  40.0
# 21                      20.0                  45.0
# 22                      19.0                  45.0
# 23                      19.0                  45.0
# 24                      17.0                  40.0
# 25                      15.0                  25.0
# 26                      15.0                  20.0
# 27                      15.0                  15.0
# 28                      14.0                  15.0
# 29                      13.0                  25.0
# 30                      13.0                  25.0
# 31                      12.0                  45.0
# 32                      12.0                  30.0
# 33                      11.0                  20.0
# 34                       7.0                  20.0
# 35                       5.0                  15.0
# 36                       5.0                  20.0
# 37                       5.0                  10.0
# 38                       5.0                   5.0
# 39                       5.0                   5.0
# 40                       NaN                   NaN
# 41                       NaN                   NaN
# 42                       NaN                   NaN
# 43                       NaN                   NaN
# 44                       NaN                   NaN
# 45                       NaN                   NaN
# 46                       NaN                   NaN
# 47                       NaN                   NaN
# 48                       NaN                   NaN
# 49                       NaN                   NaN
# 50                       NaN                   NaN
# 51                       NaN                   NaN
# 52                       NaN                   NaN
# 53                       NaN                   NaN
# 54                       NaN                   NaN
# 55                       NaN                   NaN
# 56                       NaN                   NaN
